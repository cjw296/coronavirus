# %%
import numpy as np
import pandas as pd
from constants import *
from phe import *
from plotting import *
from waves import *
import series as s

# %%
fig, rows = plt.subplots(nrows=4, ncols=1, figsize=(16, 10), dpi=150, sharex=True)
fig.set_facecolor('white')

for nation_name, row in zip(nations, rows):
    plot_summary(earliest_date='2020-02-01', show_latest='lines', log=True, ax=row, nation=nation_name, 
#                  x_labels=nation_name == 'wales',
                 left_series=(s.new_cases_sum,),
                 right_series=(s.new_admissions_sum, s.new_deaths_sum))

# %%
hospital_plot(start='2021-06', figsize=(16, 10))
