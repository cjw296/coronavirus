# %%
from bars import plot_bars
from heatmap import heatmap
from phe import demographic_stream_plot, load_demographic_data, diff

# %%
data = load_demographic_data('case_demographics_nation', 'England', 'rollingRate', start='2021-06')[0]

# %%
heatmap(data, title='Rolling rate of new cases')

# %%
heatmap(diff(data, days=7), title='Difference for rolling rate of new cases between T and T-7', 
        figsize=(16, 9), center=0, cmap='coolwarm')

# %%
demographic_stream_plot('Rate of new COVID-19 cases', order=1, band_size=10, start='2021-08', figsize=(16,10))

# %%
demographic_stream_plot('Growth in rate of new COVID-19 cases', order=2, band_size=15, start='2021-08', figsize=(16,10))

# %%
demographic_stream_plot('Growth in rate of new COVID-19 cases', order=2, band_size=10, start='2021-05-15', log=True)

# %%
plot_bars('*', 'admissions_demographics', show_title=True, earliest='2021-05-01')

# %%
plot_bars('*', 'deaths_demographics', show_title=True, earliest='2021-05-01')

# %%
plot_bars('*', 'cases_demographics', show_title=True, earliest='2021-05-01')

# %%
plot_bars('*', 'admissions_demographics_for_comparison', show_title=True, earliest='2021-05-01')

# %%
plot_bars('*', 'deaths_demographics_for_comparison', show_title=True, earliest='2021-05-01')
