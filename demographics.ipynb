# %%
from bars import plot_with_diff

# %%
plot_with_diff('*', 'deaths_demographics', show_title=True)

# %%
plot_with_diff('*', 'cases_demographics', show_title=True)

# %%
plot_with_diff('*', 'deaths_demographics_for_comparison', show_title=True)
