# %%
from bars import plot_bars
from constants import *

# %%
plot_bars('*', 'admissions_demographics', show_title=True)#, ylim=1000, earliest='2021-02-22')

# %%
plot_bars('*', 'deaths_demographics', show_title=True)

# %%
plot_bars('*', 'cases_demographics', show_title=True)

# %%
plot_bars('*', 'admissions_demographics_for_comparison', show_title=True)

# %%
plot_bars('*', 'deaths_demographics_for_comparison', show_title=True)
